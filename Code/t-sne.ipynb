# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
Y = digits.target

plt.figure(figsize = (6, 6))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(X[i].reshape(8, 8), cmap = "gray")
    plt.axis("off")
plt.suptitle("Digite Samples")
plt.show()

# %%
from sklearn.cluster import MiniBatchKMeans, clustering_error
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
kmeans1 = MiniBatchKMeans(n_clusters = 110, random_state = 42, batch_size = 128)
labels1 = kmeans1.fit_predict(X)
error1, labels1_mapped = clustering_error(y, labels1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn.cluster import MiniBatchKMeans, clustering_error
#       2 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#       3 kmeans1 = MiniBatchKMeans(n_clusters = 110, random_state = 42, batch_size = 128)
#
# ImportError: cannot import name 'clustering_error' from 'sklearn.cluster' (c:\Users\33529\anaconda3\envs\myproject\Lib\site-packages\sklearn\cluster\__init__.py)
